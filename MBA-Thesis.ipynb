# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data
df = pd.read_excel('/content/survey.xlsx')

# %%
df
# Out:
#       ID          Start time     Completion time      Email  Name  \
# 0      2 2023-12-23 19:53:23 2023-12-23 19:56:20  anonymous   NaN
# 1      3 2023-12-23 20:19:40 2023-12-23 20:21:03  anonymous   NaN
# 2      4 2023-12-23 20:18:01 2023-12-23 20:25:40  anonymous   NaN
# 3      5 2023-12-23 20:20:29 2023-12-23 20:28:38  anonymous   NaN
# 4      6 2023-12-23 20:19:09 2023-12-23 20:31:30  anonymous   NaN
# ..   ...                 ...                 ...        ...   ...
# 777  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 778  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 779  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 780  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 781  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
#
#      Last modified time What is your age?  What is your Gender?   \
# 0                   NaN              25-34                  Male
# ...

# %%
# Make sure to use the correct path to your survey file

# Checking all columns by printing them
for column in df.columns:
    print(f"'{column}'")  # This will print each column name within single quotes
# Out:
# 'ID'
# 'Start time'
# 'Completion time'
# 'Email'
# 'Name'
# 'Last modified time'
# 'What is your age? '
# 'What is your Gender? '
# 'What is your demographic location? '
# 'What is your Educational background'
# 'Brand'
# 'Rank the "product safety" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy")
# '
# 'Rank the "Ingredient transparency" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") '
# 'Rank the "Educational initiatives" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") '
# ...

# %%
df
# Out:
#       ID          Start time     Completion time      Email  Name  \
# 0      2 2023-12-23 19:53:23 2023-12-23 19:56:20  anonymous   NaN
# 1      3 2023-12-23 20:19:40 2023-12-23 20:21:03  anonymous   NaN
# 2      4 2023-12-23 20:18:01 2023-12-23 20:25:40  anonymous   NaN
# 3      5 2023-12-23 20:20:29 2023-12-23 20:28:38  anonymous   NaN
# 4      6 2023-12-23 20:19:09 2023-12-23 20:31:30  anonymous   NaN
# ..   ...                 ...                 ...        ...   ...
# 777  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 778  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 779  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 780  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
# 781  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous   NaN
#
#      Last modified time What is your age?  What is your Gender?   \
# 0                   NaN              25-34                  Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 24 columns):
#  #   Column                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                   --------------  -----
#  0   ID                                                                                                                                                                                                       782 non-null    int64
# ...

# %%
df.drop(['Name','Last modified time'], axis=1,inplace=True)

# %%
df
# Out:
#       ID          Start time     Completion time      Email  \
# 0      2 2023-12-23 19:53:23 2023-12-23 19:56:20  anonymous
# 1      3 2023-12-23 20:19:40 2023-12-23 20:21:03  anonymous
# 2      4 2023-12-23 20:18:01 2023-12-23 20:25:40  anonymous
# 3      5 2023-12-23 20:20:29 2023-12-23 20:28:38  anonymous
# 4      6 2023-12-23 20:19:09 2023-12-23 20:31:30  anonymous
# ..   ...                 ...                 ...        ...
# 777  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 778  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 779  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 780  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 781  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
#
#     What is your age?  What is your Gender?   \
# 0                25-34                  Male
# 1                18-24                Female
# 2             Above 45                Female
# 3                18-24                Female
# ...

# %% [markdown]
# # BRAND ANALYSIS
# Knowing the number of responses per brand is essential for understanding the proportionate representation of each brand in the data. This understanding is crucial when comparing brands or analyzing trends within subsets of the data.

# %%
# Count the number of responses per brand and plot
brand_counts = df['Brand'].value_counts()
brand_counts.plot(kind='bar')
plt.title('Number of Responses per Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %%
# Stripping newline characters
df.columns = df.columns.str.replace('\n', '', regex=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                   --------------  -----
#  0   ID                                                                                                                                                                                                       782 non-null    int64
# ...

# %%
# Example: Renaming the fifth column
df.columns.values[13] = "EthicalSourcingRank"
df
# Out:
#       ID          Start time     Completion time      Email  \
# 0      2 2023-12-23 19:53:23 2023-12-23 19:56:20  anonymous
# 1      3 2023-12-23 20:19:40 2023-12-23 20:21:03  anonymous
# 2      4 2023-12-23 20:18:01 2023-12-23 20:25:40  anonymous
# 3      5 2023-12-23 20:20:29 2023-12-23 20:28:38  anonymous
# 4      6 2023-12-23 20:19:09 2023-12-23 20:31:30  anonymous
# ..   ...                 ...                 ...        ...
# 777  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 778  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 779  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 780  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
# 781  214 2023-12-31 12:03:09 2023-12-31 12:03:27  anonymous
#
#     What is your age?  What is your Gender?   \
# 0                25-34                  Male
# 1                18-24                Female
# 2             Above 45                Female
# 3                18-24                Female
# ...

# %%
# Print all column names to verify the renaming operation
print(df.columns)
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Email', 'What is your age? ',
#        'What is your Gender? ', 'What is your demographic location? ',
#        'What is your Educational background', 'Brand',
#        'Rank the "product safety" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
#        'Rank the "Ingredient transparency" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
#        'Rank the "Educational initiatives" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
# ...

# %%
# Print all current column names
print(df.columns)
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Email', 'What is your age? ',
#        'What is your Gender? ', 'What is your demographic location? ',
#        'What is your Educational background', 'Brand',
#        'Rank the "product safety" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
#        'Rank the "Ingredient transparency" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
#        'Rank the "Educational initiatives" in order of importance regarding your trust in cosmetics brands :(Scale of 1 to 5, with 1 being "Not at all Trustworthy" and 5 being "Extremely Trustworthy") ',
# ...

# %%
# Strip spaces, replace remaining spaces with underscores, and convert to lowercase
df.columns = df.columns.str.strip().str.replace(' ', '_').str.lower()

# %%
# Print all current column names
print(df.columns)
# Out:
# Index(['id', 'start_time', 'completion_time', 'email', 'what_is_your_age?',
#        'what_is_your_gender?', 'what_is_your_demographic_location?',
#        'what_is_your_educational_background', 'brand',
#        'rank_the_"product_safety" in_order_of_importance_regarding_your_trust_in_cosmetics_brands_:(scale_of_1_to_5,_with_1_being_"not_at_all_trustworthy"_and_5_being_"extremely_trustworthy")',
#        'rank_the_"ingredient_transparency" in_order_of_importance_regarding_your_trust_in_cosmetics_brands_:(scale_of_1_to_5,_with_1_being_"not_at_all_trustworthy"_and_5_being_"extremely_trustworthy")',
#        'rank_the_"educational_initiatives" in_order_of_importance_regarding_your_trust_in_cosmetics_brands_:(scale_of_1_to_5,_with_1_being_"not_at_all_trustworthy"_and_5_being_"extremely_trustworthy")',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Assuming you are checking 'VariableOfInterest'
plt.hist(df['ethicalsourcingrank'], bins=20, alpha=0.7, color='blue')
plt.title('Histogram of Variable of Interest')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##  The distribution seems to be left-skewed (negatively skewed), as there is a long tail on the left side of the distribution. Most of the data are concentrated on the right side of the histogram.

# %%
# List the indices of the columns we are interested in
# Assuming the order starts at 0 and corresponds to the list provided
import seaborn as sns
column_indices = [9, 10, 11, 12, 13, 15]

# Use the column indices to plot histograms for the specified survey questions
for index in column_indices:
    col = df.columns[index]  # Get the column name using the index
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True)  # Plot the histogram
    plt.title(f'Histogram of {col}')  # Set the title to the column name
    plt.xlabel('Ratings')  # Set the x-axis label
    plt.ylabel('Frequency')  # Set the y-axis label
    plt.show()  # Show the plot

# %% [markdown]
# # Data Transformation

# %%
# Initialize a new DataFrame to store transformed data
df_transformed = pd.DataFrame()

# Apply log transformation to numeric columns while avoiding non-numeric data.
for index in column_indices:
    col = df.columns[index]
    # Check if the column is numeric
    if pd.api.types.is_numeric_dtype(df[col]):
        # If there are zero or negative values, adjust by adding a small constant
        transformed_col = np.log(df[col] + 1 - df[col].min())
        df_transformed[col + '_log'] = transformed_col
        # Plot the transformed data histogram
        plt.figure(figsize=(10, 6))
        sns.histplot(transformed_col, kde=True)
        plt.title(f'Log Transformed {col}')
        plt.xlabel('Transformed Value')
        plt.ylabel('Frequency')
        plt.show()
    else:
        print(f"Column {col} is not numeric and will be skipped.")

# %% [markdown]
# > Indented block
